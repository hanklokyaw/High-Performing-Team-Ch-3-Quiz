# %%
import random

question_count = 0
game_continue = True
question_collection = []

ques_1 = ['__________ is 5 to 7 times more important than other dimension.',
          'Quality and strength of the collaborative relationship',
          'The activation and operation of placebo, hope, and expectancy',
          'Engage and Inspire',
          'Length of coaching engagement and strength of relationship']
ques_2 = ['Models achieve their effects in larger part through __________.',
          'The activation and operation of placebo, hope, and expectancy',
          'Quality and strength of the collaborative relationship',
          'Engage and Inspire',
          'Length of coaching engagement and strength of relationship']
ques_3 = ['Coach must __________.',
          'Engage and Inspire',
          'The activation and operation of placebo, hope, and expectancy',
          'Length of coaching engagement and strength of relationship',
          'Quality and strength of the collaborative relationship']
ques_4 = ['No correlation between __________.',
          'Length of coaching engagement and strength of relationship',
          'Engage and Inspire',
          'The activation and operation of placebo, hope, and expectancy',
          'Quality and strength of the collaborative relationship']
ques_5 = ['Connection: __________.',
          'Coach needs to connect with the team',
          'Coach may share pathway to the present and/or experience',
          'Expression of enthusiasm as though each team is unique… not routine',
          'Confidence to ask few questions and let the team speak']
ques_6 = ['Confidence: __________.',
          'Coach may share pathway to the present and/or experience',
          'Expression of enthusiasm as though each team is unique… not routine',
          'Confidence to ask few questions and let the team speak',
          'Coach needs to connect with the team']
ques_7 = ['Continuting: __________.',
          'Expression of enthusiasm as though each team is unique… not routine',
          'Coach may share pathway to the present and/or experience',
          'Confidence to ask few questions and let the team speak',
          'Coach needs to connect with the team']
ques_8 = ['Courage: __________.',
          'Confidence to ask few questions and let the team speak',
          'Expression of enthusiasm as though each team is unique… not routine',
          'Coach may share pathway to the present and/or experience',
          'Coach needs to connect with the team']
ques_9 = ['Result is the ___________ of this coach.',
          '"Way of Being"',
          '"Engage and Inspire"',
          '"Confidence to ask few questions and let the team speak"',
          'Coach may share pathway to the present and/or experience']
ques_10 = ["4C's of inspire and engagement include: connection, confidence,continuing, and __________.",
           'Courage',
           'Catalyser',
           'Contract',
           'Coaching']
ques_11 = ["4C's of inspire and engagement include: __________, confidence,continuing, and courage.",
           'Connection',
           'Catalyser',
           'Contract',
           'Coaching']
ques_12 = ["4C's of inspire and engagement include: connection, __________,continuing, and courage.",
           'Confidence',
           'Catalyser',
           'Contract',
           'Coaching']
ques_13 = ["4C's of inspire and engagement include: connection, confidence,__________, and courage.",
           'Continuing',
           'Catalyser',
           'Contract',
           'Coaching']
ques_14 = ['Coach Maturity include: models based, process based, philosophy based, __________.',
           'System ecletic',
           'Assessment',
           'Review learning and successes',
           'Assimilator']
ques_15 = ['Coach Maturity include: __________, process based, philosophy based, system ecletic.',
           'Model based',
           'Assessment',
           'Review learning and successes',
           'Assimilator']
ques_16 = ['Coach Maturity include: models based, __________, philosophy based, system ecletic.',
           'Process based',
           'Assessment',
           'Review learning and successes',
           'Assimilator']
ques_17 = ['Coach Maturity include: models based, process based, __________, system ecletic.',
           'Philosophy based',
           'Assessment',
           'Review learning and successes',
           'Assimilator']
ques_18 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. Understanding of business context,\n'
           '3. Permission to talk less,\n'
           '4. Meaningful supervision,\n'
           '5. Committed to personal development,\n'
           '6. Awareness of boundaries,\n'
           '7. Sense of Progression,\n'
           '8. Knowing who best to work with,\n'
           '9. Conception of fully functioning person,\n'
           '10. __________',
           'Allows time for maturity to take place.',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_19 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. Understanding of business context,\n'
           '3. Permission to talk less,\n'
           '4. Meaningful supervision,\n'
           '5. Committed to personal development,\n'
           '6. Awareness of boundaries,\n'
           '7. Sense of Progression,\n'
           '8. Knowing who best to work with,\n'
           '9. __________,\n'
           '10. Allows time for maturity to take place.',
           'Conception of fully functioning person',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_20 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. Understanding of business context,\n'
           '3. Permission to talk less,\n'
           '4. Meaningful supervision,\n'
           '5. Committed to personal development,\n'
           '6. Awareness of boundaries,\n'
           '7. Sense of Progression,\n'
           '8. __________,\n'
           '9. Conception of fully functioning person,\n'
           '10. Allows time for maturity to take place.',
           'Knowing who best to work with',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_21 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. Understanding of business context,\n'
           '3. Permission to talk less,\n'
           '4. Meaningful supervision,\n'
           '5. Committed to personal development,\n'
           '6. Awareness of boundaries,\n'
           '7. __________,\n'
           '8. Knowing who best to work with,\n'
           '9. Conception of fully functioning person,\n'
           '10. Allows time for maturity to take place.',
           'Sense of Progression',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_22 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. Understanding of business context,\n'
           '3. Permission to talk less,\n'
           '4. Meaningful supervision,\n'
           '5. Committed to personal development,\n'
           '6. __________,\n'
           '7. Sense of Progression,\n'
           '8. Knowing who best to work with,\n'
           '9. Conception of fully functioning person,\n'
           '10. Allows time for maturity to take place.',
           'Awareness of boundaries',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_23 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. Understanding of business context,\n'
           '3. Permission to talk less,\n'
           '4. Meaningful supervision,\n'
           '5. __________,\n'
           '6. Awareness of boundaries,\n'
           '7. Sense of Progression,\n'
           '8. Knowing who best to work with,\n'
           '9. Conception of fully functioning person,\n'
           '10. Allows time for maturity to take place.',
           'Committed to personal development',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_24 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. Understanding of business context,\n'
           '3. Permission to talk less,\n'
           '4. __________,\n'
           '5. Committed to personal development,\n'
           '6. Awareness of boundaries,\n'
           '7. Sense of Progression,\n'
           '8. Knowing who best to work with,\n'
           '9. Conception of fully functioning person,\n'
           '10. Allows time for maturity to take place.',
           'Meaningful supervision',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_25 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. Understanding of business context,\n'
           '3. __________,\n'
           '4. Meaningful supervision,\n'
           '5. Committed to personal development,\n'
           '6. Awareness of boundaries,\n'
           '7. Sense of Progression,\n'
           '8. Knowing who best to work with,\n'
           '9. Conception of fully functioning person,\n'
           '10. Allows time for maturity to take place.',
           'Permission to talk less',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_26 = ['Personal philosophy includes:\n '
           '1. Sense of being based on relfection,\n'
           '2. __________,\n'
           '3. Permission to talk less,\n'
           '4. Meaningful supervision,\n'
           '5. Committed to personal development,\n'
           '6. Awareness of boundaries,\n'
           '7. Sense of Progression,\n'
           '8. Knowing who best to work with,\n'
           '9. Conception of fully functioning person,\n'
           '10. Allows time for maturity to take place.',
           'Understanding of business context',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_27 = ['Personal philosophy includes:\n '
           '1. __________,\n'
           '2. Understanding of business context,\n'
           '3. Permission to talk less,\n'
           '4. Meaningful supervision,\n'
           '5. Committed to personal development,\n'
           '6. Awareness of boundaries,\n'
           '7. Sense of Progression,\n'
           '8. Knowing who best to work with,\n'
           '9. Conception of fully functioning person,\n'
           '10. Allows time for maturity to take place.',
           'Sense of being based on relfection',
           'Review learning and successes',
           'Individual coaching',
           'Exploring and experimenting']
ques_28 = ['P.E.R.I.L.L Diagnostic Approach are:\n'
           '> Purpose and motivation\n'
           '> External processes, systems, and structures\n'
           '> Relationships\n'
           '> Internal processes, systems, and structures\n'
           '> Learning\n'
           '> __________.',
           'Leadership',
           'Listening',
           'Liaison',
           'Leverage']
ques_29 = ['P.E.R.I.L.L Diagnostic Approach are:\n'
           '> Purpose and motivation\n'
           '> External processes, systems, and structures\n'
           '> Relationships\n'
           '> Internal processes, systems, and structures\n'
           '> __________\n'
           '> Leadership.',
           'Learning',
           'Listening',
           'Liaison',
           'Leverage']
ques_29 = ['P.E.R.I.L.L Diagnostic Approach are:\n'
           '> Purpose and motivation\n'
           '> External processes, systems, and structures\n'
           '> Relationships\n'
           '> __________\n'
           '> Learning\n'
           '> Leadership.',
           'Internal processes, systems, and structures',
           'Inspire and engage',
           'Inquiry',
           'Individual coaching']
ques_30 = ['P.E.R.I.L.L Diagnostic Approach are:\n'
           '> Purpose and motivation\n'
           '> External processes, systems, and structures\n'
           '> __________\n'
           '> Internal processes, systems, and structures\n'
           '> Learning\n'
           '> Leadership.',
           'Relationships',
           'Review learning and successes',
           'Relatedness',
           'Recontracting']
ques_31 = ['P.E.R.I.L.L Diagnostic Approach are:\n'
           '> Purpose and motivation\n'
           '> __________\n'
           '> Relationships\n'
           '> Internal processes, systems, and structures\n'
           '> Learning\n'
           '> Leadership.',
           'External processes, systems, and structures',
           'Exploring',
           'Experimenting',
           'Evaluation']
ques_32 = ['P.E.R.I.L.L Diagnostic Approach are:\n'
           '> __________\n'
           '> External processes, systems, and structures\n'
           '> Relationships\n'
           '> Internal processes, systems, and structures\n'
           '> Learning\n'
           '> Leadership.',
           'Purpose and motivation',
           'Partnership',
           'Participation',
           'Planning']
ques_33 = ['Coaching engagements are contract, inquiry, ___________.',
           'Disgnosis and design', 
           'Determine',
           'Deliver',
           'Disgnosis']
ques_34 = ['Coaching engagements are contract, ___________, disgnosis and design.',
           'Inquiry', 
           'Individual',
           'Inspire',
           'Identity']
ques_35 = ['Coaching engagements are ___________, inquiry, disgnosis and design.',
           'Contract', 
           'Coaching',
           'Confident',
           'Courage']
ques_36 = ['Hawkin C.L.E.A.R models are contract, listening, exploring and experimenting, action, __________.',
           'Review and evaluation', 
           'Relationship',
           'Reflection',
           'Result']
ques_37 = ['Hawkin C.L.E.A.R models are contract, listening, exploring and experimenting, __________, review and evaluation.',
           'Action', 
           'Awareness',
           'Advisor',
           'Assimilator']
ques_38 = ['Hawkin C.L.E.A.R models are contract, listening, __________, Action, review and evaluation.',
           'Exploring and experimenting', 
           'External processes, systems, and structures',
           'Evaluation',
           'Educator']
ques_39 = ['Hawkin C.L.E.A.R models are contract, __________, exploring and experimenting, Action, review and evaluation.',
           'Listening', 
           'Leadership',
           'Learning',
           'Liaison']
ques_40 = ['Hawkin C.L.E.A.R models are __________, Listening, exploring and experimenting, Action, review and evaluation.',
           'Contract', 
           'Courage',
           'Confident',
           'Continuing']
ques_41 = ['Peters and Carr process model include: Assessment, Coaching for team design, Team launch, Individual coaching,'
           ' Ongoing team coaching, __________.',
           'Review learning and successes',
           'Purpose and motivation',
           'Sense of Progression',
           'Understanding of business context']
ques_42 = ['Peters and Carr process model include: Assessment, Coaching for team design, Team launch, Individual coaching,'
           ' __________, Review learning and successes.',
           'Ongoing team coaching',
           'Purpose and motivation',
           'Sense of Progression',
           'Understanding of business context']
ques_43 = ['Peters and Carr process model include: Assessment, Coaching for team design, Team launch, __________,'
           ' Ongoing team coaching, Review learning and successes.',
           'Individual coaching',
           'Purpose and motivation',
           'Sense of Progression',
           'Understanding of business context']
ques_44 = ['Peters and Carr process model include: Assessment, Coaching for team design, __________, Individual coaching,'
           ' Ongoing team coaching, Review learning and successes.',
           'Team launch',
           'Purpose and motivation',
           'Sense of Progression',
           'Understanding of business context']
ques_45 = ['Peters and Carr process model include: Assessment, __________, Team launch, Individual coaching,'
           ' Ongoing team coaching, Review learning and successes.',
           'Coaching for team design',
           'Purpose and motivation',
           'Sense of Progression',
           'Understanding of business context']
ques_46 = ['Peters and Carr process model include: __________, Coaching for team design, Team launch, Individual coaching,'
           ' Ongoing team coaching, Review learning and successes.',
           'Assessment',
           'Purpose and motivation',
           'Sense of Progression',
           'Understanding of business context']
ques_47 = ['In high performance team coaching, three main points of __________ are:\n'
           '1. New team(define and initiate)\n'
           '2. Midpoint(review and realign)\n'
           '3. Ending(reassess and integrate)',
           'Intervention and impact',
           'Purpose and motivation',
           'Exploring and experimenting',
           'Meaningful supervision']
ques_48 = ['In high performance team coaching, three main points of intervention and impact are:\n'
           '1. New team(__________)\n'
           '2. Midpoint(review and realign)\n'
           '3. Ending(reassess and integrate)',
           'Define and initiate',
           'Purpose and motivate',
           'Explore and experiment',
           'Design and Innovate']
ques_49 = ['In high performance team coaching, three main points of intervention and impact are:\n'
           '1. New team(define and initiate)\n'
           '2. Midpoint(__________)\n'
           '3. Ending(reassess and integrate)',
           'Review and realign',
           'Review learning and successes',
           'Review and evaluation',
           'Redesign and iterate']
ques_50 = ['In high performance team coaching, three main points of intervention and impact are:\n'
           '1. New team(define and initiate)\n'
           '2. Midpoint(review and realign)\n'
           '3. Ending(__________)',
           'Reassess and integrate',
           'Review learning and successes',
           'Review and evaluation',
           'Redesign and iterate']
ques_51 = ["Hauser's shape shifting model includes: coach behaviour focus, advisor, educator, catalyser, __________",
           'Assimilator',
           'Review and evaluation',
           'Action',
           'Diagnosis and Design']
ques_52 = ["Hauser's shape shifting model includes: coach behaviour focus, advisor, educator, __________, Assimilator",
           'Catalyser',
           'Review and evaluation',
           'Action',
           'Diagnosis and Design']
ques_53 = ["Hauser's shape shifting model includes: coach behaviour focus, advisor, __________, catalyser, assimilator",
           'Educator',
           'Review and evaluation',
           'Action',
           'Diagnosis and Design']
ques_54 = ["Hauser's shape shifting model includes: coach behaviour focus, __________, educator, catalyser, assimilator",
           'Advisor',
           'Review and evaluation',
           'Action',
           'Diagnosis and Design']
ques_55 = ["Hauser's shape shifting model includes: __________, advisor, educator, catalyser, assimilator",
           'Coach behaviour focus',
           'Contract',
           'Inquiry',
           'Diagnosis and Design']
ques_56 = ['Team edge model are:\n'
           'Purpose\n'
           'Value & Beliefs, and Identity\n'
           'Awareness, Relatedness, Ways or working, and __________',
           'Transrormation',
           'Review',
           'Diagnosis',
           'Action']
ques_57 = ['Team edge model are:\n'
           'Purpose\n'
           'Value & Beliefs, and Identity\n'
           'Awareness, Relatedness, __________, and Transrormation',
           'Ways or working',
           'Review',
           'Diagnosis',
           'Action']
ques_58 = ['Team edge model are:\n'
           'Purpose\n'
           'Value & Beliefs, and Identity\n'
           'Awareness, __________, Ways or working, and Transrormation',
           'Relatedness',
           'Review',
           'Diagnosis',
           'Action']
ques_59 = ['Team edge model are:\n'
           'Purpose\n'
           'Value & Beliefs, and Identity\n'
           '__________, Relatedness, Ways or working, and Transrormation',
           'Awareness',
           'Review',
           'Diagnosis',
           'Action']
ques_60 = ['Team edge model are:\n'
           'Purpose\n'
           'Value & Beliefs, and __________\n'
           'Awareness, Relatedness, Ways or working, and Transrormation',
           'Identity',
           'Contract',
           'Courage',
           'Confident']
ques_61 = ['Team edge model are:\n'
           'Purpose\n'
           '__________, and Identity\n'
           'Awareness, Relatedness, Ways or working, and Transrormation',
           'Value & Beliefs',
           'Engage and Inspire',
           'Purpose and motivation',
           'Exploring and experimenting']
ques_62 = ['Team edge model are:\n'
           '__________\n'
           'Value & Beliefs, and Identity\n'
           'Awareness, Relatedness, Ways or working, and Transrormation',
           'Purpose',
           'Inspire',
           'Motivation',
           'Exploration']
ques_63 = ['Widdowson steps are:\n'
           'Stage 1 - Pre-team coaching\n'
           'Stage 2 - Interview and team diagnostic\n'
           'Stage 3- Co-design team coaching\n'
           'Stage 4 - Workshop 1\n'
           'Stage 5 - Workshop 2\n'
           'Stage 6 - Workshop 3+\n'
           'Stage 7 - __________',
           'Evaluation',
           'Review',
           'Transformation',
           'Relatedness']
ques_64 = ['Widdowson steps are:\n'
           'Stage 1 - Pre-team coaching\n'
           'Stage 2 - Interview and team diagnostic\n'
           'Stage 3- Co-design team coaching\n'
           'Stage 4 - Workshop 1\n'
           'Stage 5 - Workshop 2\n'
           'Stage 6 - __________\n'
           'Stage 7 - Evaluation',
           'Workshop 3+',
           'Review',
           'Transformation',
           'Relatedness']
ques_65 = ['Widdowson steps are:\n'
           'Stage 1 - Pre-team coaching\n'
           'Stage 2 - Interview and team diagnostic\n'
           'Stage 3- __________\n'
           'Stage 4 - Workshop 1\n'
           'Stage 5 - Workshop 2\n'
           'Stage 6 - Workshop 3+\n'
           'Stage 7 - Evaluation',
           'Co-design team coaching',
           'Review',
           'Transformation',
           'Relatedness']
ques_66 = ['Widdowson steps are:\n'
           'Stage 1 - Pre-team coaching\n'
           'Stage 2 - __________\n'
           'Stage 3- Co-design team coaching\n'
           'Stage 4 - Workshop 1\n'
           'Stage 5 - Workshop 2\n'
           'Stage 6 - Workshop 3+\n'
           'Stage 7 - Evaluation',
           'Interview and team diagnostic',
           'Review',
           'Transformation',
           'Relatedness']
ques_67 = ['Widdowson steps are:\n'
           'Stage 1 - __________\n'
           'Stage 2 - Interview and team diagnostic\n'
           'Stage 3- Co-design team coaching\n'
           'Stage 4 - Workshop 1\n'
           'Stage 5 - Workshop 2\n'
           'Stage 6 - Workshop 3+\n'
           'Stage 7 - Evaluation',
           'Pre-team coaching',
           'Review',
           'Transformation',
           'Relatedness']


# does not work
# # # add all questions into question bank
# for ques in range(1,77):
#     question_collection.append(f'ques_{ques}')
#     question_collection_joined = ('[%s]' % ', '.join(map(str, question_collection)))
# print(question_collection_joined)

    
# manual add questions into question bank
question_collection = [ques_1, ques_2, ques_3, ques_4, ques_5, ques_6, ques_7, ques_8, ques_9, ques_10, ques_11, ques_12,
                      ques_13, ques_14, ques_15, ques_16, ques_17, ques_18, ques_19, ques_20, ques_21, ques_22, ques_23,
                      ques_24, ques_25, ques_26, ques_27, ques_28, ques_29, ques_30, ques_31, ques_32, ques_33, ques_34, 
                      ques_35, ques_36, ques_37, ques_38, ques_39, ques_40, ques_41, ques_42, ques_43, ques_44, ques_45,
                      ques_46, ques_47, ques_48, ques_49, ques_50, ques_51, ques_52, ques_53, ques_54, ques_55, ques_56,
                      ques_57, ques_58, ques_59, ques_60, ques_61, ques_62, ques_63, ques_64, ques_65, ques_66, ques_67]

while game_continue:
    question = random.choice(question_collection)
    question_count += 1
    shuffle_lst = question[1:]
    random.shuffle(shuffle_lst)
    correct_choice = 0
    print("\n", '-' * 50, 'NEXT', '-' * 50, '\n')
    print(f'{question_count}. {question[0]}\n')
    for ans in range(1,5):
        print(f"{ans}. ", shuffle_lst[ans - 1])
        if shuffle_lst[ans - 1] == question[1]:
            correct_choice = ans
    user_input = input('\n> ')
    user_input = int(user_input)
    
    
    try:
        
        if user_input == correct_choice:
            print("\n *** Correct! *** ")
        else:
            print(f'\n--- Incorrect!, the answer is >>> {question[1]} ---')
    except:
        print("Some bug in the app!")
# Out:
#  -------------------------------------------------- NEXT --------------------------------------------------
#
# 1. Peters and Carr process model include: Assessment, __________, Team launch, Individual coaching, Ongoing team coaching, Review learning and successes.
#
# 1.  Understanding of business context
# 2.  Purpose and motivation
# 3.  Sense of Progression
# 4.  Coaching for team design
#
# > 4
#
#  *** Correct! ***
#
#  -------------------------------------------------- NEXT --------------------------------------------------
#
# 2. Personal philosophy includes:
#  1. Sense of being based on relfection,
# 2. Understanding of business context,
# 3. Permission to talk less,
# 4. Meaningful supervision,
# 5. Committed to personal development,
# 6. Awareness of boundaries,
# 7. Sense of Progression,
# 8. Knowing who best to work with,
# 9. Conception of fully functioning person,
# 10. __________
#
# 1.  Allows time for maturity to take place.
# 2.  Review learning and successes
# ...

# %%
import random

mylist = ["apple", "banana", "cherry"]
rand_shuf = random.shuffle(mylist)

print(rand_shuf)
# Out:
# None
